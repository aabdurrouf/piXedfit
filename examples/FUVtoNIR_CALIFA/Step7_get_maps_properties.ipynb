# %% [markdown]
# # 7. Get maps of stellar population properties
#
# <Font size="4"> Once we have performed SED fitting to all spatial bins in the galaxy, we can extract maps of properties from the collections of those fitting results (in FITS files). For this, we can use `maps_parameters` function in the `piXedfit_fitting` module.

# %%
import numpy as np
from astropy.io import fits
import os, sys
import matplotlib.pyplot as plt

global PIXEDFIT_HOME
PIXEDFIT_HOME = os.environ['PIXEDFIT_HOME']
sys.path.insert(0, PIXEDFIT_HOME)

# %matplotlib inline

# %% [markdown]
# <Font size="4"> Below is an example of script for constructing maps of parameters from the fitting results of spatial bins.

# %%
from piXedfit.piXedfit_fitting import maps_parameters

fits_binmap = "pixbin_corr_specphoto_fluxmap_ngc309.fits"
hdu = fits.open(fits_binmap)
nbins = int(hdu[0].header['NBINSPH'])
hdu.close()

bin_ids = []
name_sampler_fits = []
for ii in range(0,nbins):
        bin_ids.append(ii)
        name = "mcmc_bin%d.fits" % (ii+1)
        name_sampler_fits.append(name)

fits_fluxmap = "corr_specphoto_fluxmap_ngc309.fits"

name_out_fits = "maps_properties.fits"
maps_parameters(fits_binmap=fits_binmap, bin_ids=bin_ids, name_sampler_fits=name_sampler_fits,
                fits_fluxmap=fits_fluxmap,refband_SFR=0, refband_SM=11, name_out_fits=name_out_fits)

# %% [markdown]
# ### Check Maps of properties

# %%
maps = fits.open("maps_properties.fits")
maps.info()

# the galaxy's region
gal_region = maps['galaxy_region'].data
# Out:
# Filename: maps_properties.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      46   ()
#   1  GALAXY_REGION    1 ImageHDU         8   (131, 131)   float64
#   2  BIN-LOGZSOL-P16    1 ImageHDU         8   (131, 131)   float64
#   3  BIN-LOGZSOL-P50    1 ImageHDU         8   (131, 131)   float64
#   4  BIN-LOGZSOL-P84    1 ImageHDU         8   (131, 131)   float64
#   5  BIN-LOG_TAU-P16    1 ImageHDU         8   (131, 131)   float64
#   6  BIN-LOG_TAU-P50    1 ImageHDU         8   (131, 131)   float64
#   7  BIN-LOG_TAU-P84    1 ImageHDU         8   (131, 131)   float64
#   8  BIN-LOG_ALPHA-P16    1 ImageHDU         8   (131, 131)   float64
#   9  BIN-LOG_ALPHA-P50    1 ImageHDU         8   (131, 131)   float64
#  10  BIN-LOG_ALPHA-P84    1 ImageHDU         8   (131, 131)   float64
#  11  BIN-LOG_BETA-P16    1 ImageHDU         8   (131, 131)   float64
#  12  BIN-LOG_BETA-P50    1 ImageHDU         8   (131, 131)   float64
#  13  BIN-LOG_BETA-P84    1 ImageHDU         8   (131, 131)   float64
#  14  BIN-LOG_AGE-P16    1 ImageHDU         8   (131, 131)   float64
#  15  BIN-LOG_AGE-P50    1 ImageHDU         8   (131, 131)   float64
#  16  BIN-LOG_AGE-P84    1 ImageHDU         8   (131, 131)   float64
#  17  BIN-DUST_INDEX-P16    1 ImageHDU         8   (131, 131)   float64
#  18  BIN-DUST_INDEX-P50    1 ImageHDU         8   (131, 131)   float64
#  19  BIN-DUST_INDEX-P84    1 ImageHDU         8   (131, 131)   float64
#  20  BIN-DUST1-P16    1 ImageHDU         8   (131, 131)   float64
#  21  BIN-DUST1-P50    1 ImageHDU         8   (131, 131)   float64
#  22  BIN-DUST1-P84    1 ImageHDU         8   (131, 131)   float64
#  23  BIN-DUST2-P16    1 ImageHDU         8   (131, 131)   float64
#  24  BIN-DUST2-P50    1 ImageHDU         8   (131, 131)   float64
#  25  BIN-DUST2-P84    1 ImageHDU         8   (131, 131)   float64
#  26  BIN-LOG_MASS-P16    1 ImageHDU         8   (131, 131)   float64
#  27  BIN-LOG_MASS-P50    1 ImageHDU         8   (131, 131)   float64
#  28  BIN-LOG_MASS-P84    1 ImageHDU         8   (131, 131)   float64
#  29  BIN-LOG_SFR-P16    1 ImageHDU         8   (131, 131)   float64
#  30  BIN-LOG_SFR-P50    1 ImageHDU         8   (131, 131)   float64
#  31  BIN-LOG_SFR-P84    1 ImageHDU         8   (131, 131)   float64
#  32  BIN-LOG_MW_AGE-P16    1 ImageHDU         8   (131, 131)   float64
#  33  BIN-LOG_MW_AGE-P50    1 ImageHDU         8   (131, 131)   float64
#  34  BIN-LOG_MW_AGE-P84    1 ImageHDU         8   (131, 131)   float64
#  35  PIX-LOG_MASS-P16    1 ImageHDU         8   (131, 131)   float64
#  36  PIX-LOG_MASS-P50    1 ImageHDU         8   (131, 131)   float64
#  37  PIX-LOG_MASS-P84    1 ImageHDU         8   (131, 131)   float64
#  38  PIX-LOG_SFR-P16    1 ImageHDU         8   (131, 131)   float64
#  39  PIX-LOG_SFR-P50    1 ImageHDU         8   (131, 131)   float64
#  40  PIX-LOG_SFR-P84    1 ImageHDU         8   (131, 131)   float64

# %%
from piXedfit.piXedfit_images import kpc_per_pixel

z = float(maps[0].header['gal_z'])
arcsec_per_pixel = 1.5                         # pixel size in arcsec
kpc_per_pix = kpc_per_pixel(z,arcsec_per_pixel)
print ("kpc/pixel = %lf" % kpc_per_pix)
# Out:
# kpc/pixel = 0.575187

# %%
rows, cols = np.where(gal_region == 0) # get pixels outside the galaxy's region of interest

# SM:
map_prop_SM = np.log10(np.power(10.0,maps['pix-log_mass-p50'].data)/kpc_per_pix/kpc_per_pix)
map_prop_SM[rows,cols] = np.log10(-99)  # to produce nan, so that it doesn't appear in the plot

# SFR:
map_SFR = np.log10(np.power(10.0,maps['pix-log_sfr-p50'].data)/kpc_per_pix/kpc_per_pix)
map_SFR[rows,cols] = np.log10(-99)  # to produce nan, so that it doesn't appear in the plot

# Av:
map_Av = 1.086*maps['bin-dust2-p50'].data
map_Av[rows,cols] = np.log10(-99)  # to produce nan, so that it doesn't appear in the plot

# Z:
map_logzsol  = maps['bin-logzsol-p50'].data
map_logzsol[rows,cols] = np.log10(-99)  # to produce nan, so that it doesn't appear in the plot

# Mass-weighted age
map_mw_age  = np.power(10.0,maps['bin-log_mw_age-p50'].data)
map_mw_age[rows,cols] = np.log10(-99)  # to produce nan, so that it doesn't appear in the plot

# age
map_age  = np.power(10.0,maps['bin-log_age-p50'].data)
map_age[rows,cols] = np.log10(-99)  # to produce nan, so that it doesn't appear in the plot

# %%
# %matplotlib inline

from mpl_toolkits.axes_grid1 import make_axes_locatable

fig1 = plt.figure(figsize=(14,7))

###=> SFR:
f1 = fig1.add_subplot(2, 3, 1)
#plt.xlabel('[pixel]', fontsize=14)
plt.ylabel('[pixel]', fontsize=14)
plt.setp(f1.get_xticklabels(), fontsize=11)
plt.setp(f1.get_yticklabels(), fontsize=11)

plt.imshow(map_SFR, origin='lower', interpolation='bicubic', cmap='nipy_spectral')
ax = plt.gca()
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
cb = plt.colorbar(cax=cax)
cb.set_label(r'log($\Sigma_{SFR}[M_{\odot}yr^{-1}kpc^{-2}]$)', fontsize=15)


###=> SM:
f1 = fig1.add_subplot(2, 3, 2)
plt.setp(f1.get_xticklabels(), fontsize=11)
plt.setp(f1.get_yticklabels(), fontsize=11)

plt.imshow(map_prop_SM, origin='lower', interpolation='bicubic', cmap='nipy_spectral')
ax = plt.gca()
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
cb = plt.colorbar(cax=cax)
cb.set_label(r'log($\Sigma_{*}[M_{\odot}kpc^{-2}]$)', fontsize=15)

###=> AV
f1 = fig1.add_subplot(2, 3, 3)
plt.xlabel('[pixel]', fontsize=14)
plt.setp(f1.get_xticklabels(), fontsize=11)
plt.setp(f1.get_yticklabels(), fontsize=11)

plt.imshow(map_Av, origin='lower', cmap='nipy_spectral')
ax = plt.gca()
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
cb = plt.colorbar(cax=cax)
cb.set_label(r'$A_{V}$', fontsize=18)

### MW-Age:
f1 = fig1.add_subplot(2, 3, 4)
plt.xlabel('[pixel]', fontsize=14)
plt.ylabel('[pixel]', fontsize=14)
plt.setp(f1.get_xticklabels(), fontsize=11)
plt.setp(f1.get_yticklabels(), fontsize=11)

plt.imshow(map_age, origin='lower', cmap='nipy_spectral')
ax = plt.gca()
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
cb = plt.colorbar(cax=cax)
cb.set_label('Age[Gyr]', fontsize=15)

### Z:
f1 = fig1.add_subplot(2, 3, 5)
plt.xlabel('[pixel]', fontsize=14)
plt.setp(f1.get_xticklabels(), fontsize=11)
plt.setp(f1.get_yticklabels(), fontsize=11)

plt.imshow(map_logzsol, origin='lower', cmap='nipy_spectral')
ax = plt.gca()
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="5%", pad=0.05)
cb = plt.colorbar(cax=cax)
cb.set_label(r'log($Z/Z_{\odot}$)', fontsize=17)


plt.subplots_adjust(left=0.07, right=0.95, bottom=0.1, top=0.98, hspace=0.2, wspace=0.3)
plt.show()
